# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn-v0_8')

df = pd.read_csv(
    '../data/dados_inmet.csv',
    sep=';',
    encoding='latin-1',
    skiprows=10
)

df.head()
# Out:
#   Data Medicao EVAPORACAO DO PICHE, DIARIA(mm) INSOLACAO TOTAL, DIARIO(h)  \
# 0   1961-01-01                               1                          1
# 1   1961-01-02                               1                         ,4
# 2   1961-01-03                              ,5                         ,9
# 3   1961-01-04                              ,5                          0
# 4   1961-01-05                              ,3                          0
#
#   PRECIPITACAO TOTAL, DIARIO(mm) TEMPERATURA MAXIMA, DIARIA(Â°C)  \
# 0                           30,3                            24,8
# 1                           10,6                            23,8
# 2                           36,1                            24,7
# 3                           38,1                            21,4
# 4                           67,1                            22,4
#
#   TEMPERATURA MEDIA COMPENSADA, DIARIA(Â°C) TEMPERATURA MINIMA, DIARIA(Â°C)  \
# ...
